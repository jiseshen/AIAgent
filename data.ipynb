# %%
import json
from datasets import Dataset, DatasetDict
import random
import os

with open('data.json', "r") as f:
    data = json.load(f)
print(len(data))


def display_data(data):
    for item in data:
        print(item + ":")
        print(data[item])

for i in range(len(data)):
    data[i]["flag"] = data[i]["label"]
    del data[i]["label"]
    data[i]["reasoning"] = "\n".join(data[i]["reasoning"])

depth_5 = random.sample([i for i in data if i["depth"] > 4], 125)
depth_4 = random.sample([i for i in data if i["depth"] == 4], 250)
depth_3 = [i for i in data if i["depth"] <= 3]

train_index = random.sample(range(len(depth_3)), 1000)
test_index = [i for i in range(len(depth_3)) if i not in train_index]

train_data = Dataset.from_list([depth_3[i] for i in train_index])
test_data = Dataset.from_list([depth_3[i] for i in test_index])
ood_data = Dataset.from_list(depth_4 + depth_5)

dataset = DatasetDict({
    "train": train_data,
    "test": test_data,
    "ood_test": ood_data
})

dataset.push_to_hub("ruletaker", token=os.environ["HF_TOKEN"])
# Out:
# 2844
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/956 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/Jise/ruletaker/commit/b6e36448e186cde51052e978da0465d84da06f31', commit_message='Upload dataset', commit_description='', oid='b6e36448e186cde51052e978da0465d84da06f31', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/Jise/ruletaker', endpoint='https://huggingface.co', repo_type='dataset', repo_id='Jise/ruletaker'), pr_revision=None, pr_num=None)

# %%
count = 0
for i in dataset:
    if i["depth"] > 4:
        count += 1
print(count)
# Out:
# 17

# %%
depth_5 = [i for i in dataset if i["depth"] > 4]
depth_4 = [i for i in dataset if i["depth"] == 4]
depth_3 = [i for i in dataset if i["depth"] == 3]
depth_2 = [i for i in dataset if i["depth"] == 2]
depth_1 = [i for i in dataset if i["depth"] == 1]

# %%
for i in depth_4:
    if i["label"] == "False":
        continue
    print(i["context"])
    print("\n")
    print(i["statement"])
    print("\n")
    print("\n".join(i["reasoning"]))
    print("\n")
    print(i["label"])
    print("--------------------")
# Out:
# Facts:
# The cat is an engineer.
# The cat hosts parties.
# The cat is an engineer.
# Rules:
# Given that the cat is an engineer, it follows that the cat takes pictures.
# If the cat hosts parties, then the mountain is an engineer.
# Given that the cat is an engineer, it follows that the garden is an engineer.
# When the cat is an engineer, we can conclude the cat takes pictures.
# Based on the cat hosts parties, it is evident that the mountain is an engineer.
# When the mountain takes pictures, we can conclude the garden is an engineer.
# Given that the mountain is an engineer, it follows that the mountain takes pictures.
# When the cat hosts parties, we can conclude the mountain is an engineer.
# If the cat takes pictures, then the cat hosts parties.
# Given that the cat takes pictures, it follows that the garden is an engineer.
#
#
# The garden is an engineer.
#
#
# Since we know that when the cat is an engineer, we can conclude the cat takes pictures, it follows that the cat takes pictures.
# Given that based on the cat takes pictures, it is evident that the cat hosts parties, it is evident that the cat hosts parties.
# Since we know that if the cat hosts parties, then the mountain is an engineer, it follows that the mountain is an engineer.
# Applying the logic of if the mountain is an engineer, then the mountain takes pictures, we deduce that the mountain takes pictures.
# Applying the logic of when the mountain takes pictures, we can conclude the garden is an engineer, we deduce that the garden is an engineer.
#
#
# True
# --------------------
# Facts:
# Jack runs quickly.
# The sun is interesting.
# Charlie runs quickly.
# Rules:
# Given that the sun is interesting, it follows that charlie teaches math.
# Assuming charlie runs quickly, we can say charlie teaches math.
# When the sun is interesting, we can conclude jack reads books.
# Given that charlie runs quickly, it follows that charlie teaches math.
# Based on the sun is interesting, it is evident that jack reads books.
# When the sun runs quickly, we can conclude jack is interesting.
# When the sun runs quickly, we can conclude the sun runs quickly.
# Assuming the sun is interesting, we can say jack reads books.
# Based on the sun is interesting, it is evident that the sun runs quickly.
# If jack reads books, then the sun is interesting.
#
#
# Jack is interesting.
#
#
# Given that if the sun is interesting, then jack reads books, it is evident that jack reads books.
# Applying the logic of when jack reads books, we can conclude the sun is interesting, we deduce that the sun is interesting.
# Because when the sun is interesting, we can conclude the sun runs quickly, we can conclude that the sun runs quickly.
# Applied Rule: since the fact that when the sun runs quickly, we can conclude the sun runs quickly, we can see that the sun runs quickly.
# Given that when the sun runs quickly, we can conclude jack is interesting, it is evident that jack is interesting.
#
#
# True
# --------------------
# Facts:
# Liam hikes mountains.
# The bakery hikes mountains.
# The train collects stamps.
# Rules:
# If liam hikes mountains, then the bakery hikes mountains.
# Assuming the train collects stamps, we can say the bakery hikes mountains.
# Based on the train collects stamps, it is evident that liam draws maps.
# If the bakery hikes mountains, then liam hikes mountains.
# When the bakery hikes mountains, we can conclude the bakery collects stamps.
# When the bakery hikes mountains, we can conclude liam draws maps.
# Assuming the train draws maps, we can say the bakery hikes mountains.
# If liam collects stamps, then the train draws maps.
# If the bakery hikes mountains, then liam collects stamps.
# When the train draws maps, we can conclude the bakery hikes mountains.
#
#
# Liam draws maps.
#
#
# Applied Rule: since the fact that assuming the bakery hikes mountains, we can say liam collects stamps, we can see that liam collects stamps.
# Given that based on liam collects stamps, it is evident that the train draws maps, it is evident that the train draws maps.
# Applying the logic of given that the train draws maps, it follows that the bakery hikes mountains, we deduce that the bakery hikes mountains.
# Because assuming the bakery hikes mountains, we can say liam draws maps, we can conclude that liam draws maps.
#
#
# True
# --------------------
# Facts:
# Ethan cooks well.
# The pig explores cities.
# The sky cooks well.
# Rules:
# Assuming ethan cooks well, we can say ethan explores cities.
# Given that the pig explores cities, it follows that sophie cooks well.
# If ethan cooks well, then ethan cooks well.
# If the sky cooks well, then ethan explores cities.
# Assuming ethan cooks well, we can say ethan explores cities.
# When the pig cooks well, we can conclude sophie cooks well.
# Given that the pig cooks well, it follows that the pig cooks well.
# When sophie volunteers, we can conclude the pig cooks well.
# When the pig cooks well, we can conclude sophie volunteers.
# Based on the pig explores cities, it is evident that the pig cooks well.
#
#
# The pig cooks well.
#
#
# Applying the logic of assuming the pig explores cities, we can say the pig cooks well, we deduce that the pig cooks well.
# Given that assuming the pig cooks well, we can say sophie volunteers, it is evident that sophie volunteers.
# Because assuming sophie volunteers, we can say the pig cooks well, we can conclude that the pig cooks well.
# Applied Rule: since the fact that given that the pig cooks well, it follows that the pig cooks well, we can see that the pig cooks well.
#
#
# True
# --------------------
# Facts:
# The zoo runs marathons.
# The sun runs marathons.
# Liam hosts parties.
# Rules:
# Based on the zoo runs marathons, it is evident that the sun is colorful.
# When liam hosts parties, we can conclude the sun runs marathons.
# If liam hosts parties, then liam plays instruments.
# Based on the zoo runs marathons, it is evident that the sun is colorful.
# When liam hosts parties, we can conclude the sun runs marathons.
# When the zoo runs marathons, we can conclude the sun is colorful.
# Assuming the sun hosts parties, we can say the zoo runs marathons.
# If the sun plays instruments, then the sun hosts parties.
# If the sun runs marathons, then the sun plays instruments.
# Given that the sun is colorful, it follows that liam plays instruments.
#
#
# The sun is colorful.
#
#
# Because if liam hosts parties, then the sun runs marathons, we can conclude that the sun runs marathons.
# Because given that the sun runs marathons, it follows that the sun plays instruments, we can conclude that the sun plays instruments.
# Given that when the sun plays instruments, we can conclude the sun hosts parties, it is evident that the sun hosts parties.
# Because if the sun hosts parties, then the zoo runs marathons, we can conclude that the zoo runs marathons.
# Since we know that when the zoo runs marathons, we can conclude the sun is colorful, it follows that the sun is colorful.
#
#
# True
# --------------------
# Facts:
# The shop is a doctor.
# James is tall.
# The shop plays football.
# Rules:
# If the shop is a doctor, then james is tall.
# Based on the shop is a doctor, it is evident that james is tall.
# When james is tall, we can conclude james dances gracefully.
# Given that james is tall, it follows that james is tall.
# If james is tall, then james dances gracefully.
# When the shop plays football, we can conclude the playground plays football.
# If the playground dances gracefully, then the shop is a doctor.
# Based on the bakery is a doctor, it is evident that the playground dances gracefully.
# If the playground is a doctor, then the bakery is a doctor.
# Assuming james is tall, we can say the playground is a doctor.
#
#
# The shop is a doctor.
#
#
# Given that when the shop is a doctor, we can conclude james is tall, it is evident that james is tall.
# Applied Rule: since the fact that when james is tall, we can conclude the playground is a doctor, we can see that the playground is a doctor.
# Because when the playground is a doctor, we can conclude the bakery is a doctor, we can conclude that the bakery is a doctor.
# Applied Rule: since the fact that assuming the bakery is a doctor, we can say the playground dances gracefully, we can see that the playground dances gracefully.
# Applied Rule: since the fact that based on the playground dances gracefully, it is evident that the shop is a doctor, we can see that the shop is a doctor.
#
#
# True
# --------------------
# Facts:
# Stanford University goes to the hospital.
# Stanford University enjoys music.
# Henry hosts parties.
# Rules:
# Based on henry hosts parties, it is evident that the stadium is an engineer.
# Given that henry hosts parties, it follows that the stadium hosts parties.
# Assuming henry hosts parties, we can say stanford university enjoys music.
# When stanford university goes to the hospital, we can conclude the stadium is an engineer.
# Assuming stanford university goes to the hospital, we can say stanford university enjoys music.
# Assuming james hosts parties, we can say stanford university is an engineer.
# Given that james is an engineer, it follows that james hosts parties.
# Based on james goes to the hospital, it is evident that james is an engineer.
# Assuming stanford university goes to the hospital, we can say james hosts parties.
# Assuming stanford university enjoys music, we can say james goes to the hospital.
#
#
# Stanford University is an engineer.
#
#
# Since we know that based on henry hosts parties, it is evident that stanford university enjoys music, it follows that stanford university enjoys music.
# Given that if stanford university enjoys music, then james goes to the hospital, it is evident that james goes to the hospital.
# Applying the logic of if james goes to the hospital, then james is an engineer, we deduce that james is an engineer.
# Because if james is an engineer, then james hosts parties, we can conclude that james hosts parties.
# Given that when james hosts parties, we can conclude stanford university is an engineer, it is evident that stanford university is an engineer.
#
#
# True
# --------------------
# Facts:
# The ocean swims well.
# The ocean cooks well.
# The ocean jumps high.
# Rules:
# Given that the ocean swims well, it follows that the ocean swims well.
# When the ocean cooks well, we can conclude ava cooks well.
# When the ocean cooks well, we can conclude the ocean cooks well.
# When the ocean cooks well, we can conclude ava cooks well.
# If the ocean cooks well, then the ocean swims well.
# Given that the ocean dances gracefully, it follows that the ocean cooks well.
# When the teacher swims well, we can conclude charlie cooks well.
# Given that ava cooks well, it follows that the ocean dances gracefully.
# Assuming ava cooks well, we can say the teacher swims well.
# Assuming the ocean cooks well, we can say ava cooks well.
#
#
# Charlie cooks well.
#
#
# Applied Rule: since the fact that if the ocean cooks well, then ava cooks well, we can see that ava cooks well.
# Since we know that when ava cooks well, we can conclude the ocean dances gracefully, it follows that the ocean dances gracefully.
# Applying the logic of based on the ocean dances gracefully, it is evident that the ocean cooks well, we deduce that the ocean cooks well.
# Because assuming the ocean cooks well, we can say ava cooks well, we can conclude that ava cooks well.
# Applying the logic of when ava cooks well, we can conclude the teacher swims well, we deduce that the teacher swims well.
# Because if the teacher swims well, then charlie cooks well, we can conclude that charlie cooks well.
#
#
# True
# --------------------
# Facts:
# Charlie is interesting.
# Charlie is friendly.
# The chef creates art.
# Rules:
# When the chef creates art, we can conclude the river is interesting.
# Assuming charlie is interesting, we can say the river is interesting.
# If the chef creates art, then the river is a chef.
# If the chef creates art, then the river is a chef.
# Given that charlie is interesting, it follows that the river is interesting.
# When the dog is friendly, we can conclude the river is a chef.
# If the dog is interesting, then the chef creates art.
# Assuming the dog is friendly, we can say the dog is interesting.
# Assuming the chef is a chef, we can say the dog is friendly.
# Given that the river is interesting, it follows that the chef is a chef.
#
#
# The chef creates art.
#
#
# Applied Rule: since the fact that if the chef creates art, then the river is interesting, we can see that the river is interesting.
# Applied Rule: since the fact that given that the river is interesting, it follows that the chef is a chef, we can see that the chef is a chef.
# Applied Rule: since the fact that assuming the chef is a chef, we can say the dog is friendly, we can see that the dog is friendly.
# Since we know that if the dog is friendly, then the dog is interesting, it follows that the dog is interesting.
# Given that if the dog is interesting, then the chef creates art, it is evident that the chef creates art.
#
#
# True
# --------------------
# Facts:
# The pig grows plants.
# The house volunteers.
# The house volunteers.
# Rules:
# Given that the pig grows plants, it follows that the playground jumps high.
# Given that the house volunteers, it follows that the playground is a doctor.
# Based on the house volunteers, it is evident that the playground is a doctor.
# Assuming the house volunteers, we can say the pig volunteers.
# When the pig grows plants, we can conclude the pig volunteers.
# Based on sophie grows plants, it is evident that the house volunteers.
# Assuming the pig grows plants, we can say sophie grows plants.
# When the playground jumps high, we can conclude sophie is a doctor.
# When sophie is a doctor, we can conclude the pig grows plants.
# Based on the playground is a doctor, it is evident that sophie is a doctor.
#
#
# The house volunteers.
#
#
# Because assuming the house volunteers, we can say the playground is a doctor, we can conclude that the playground is a doctor.
# Because assuming the playground is a doctor, we can say sophie is a doctor, we can conclude that sophie is a doctor.
# Given that given that sophie is a doctor, it follows that the pig grows plants, it is evident that the pig grows plants.
# Given that when the pig grows plants, we can conclude sophie grows plants, it is evident that sophie grows plants.
# Applying the logic of assuming sophie grows plants, we can say the house volunteers, we deduce that the house volunteers.
#
#
# True
# --------------------
# Facts:
# Charlie solves puzzles.
# Sarah solves puzzles.
# Charlie solves puzzles.
# Rules:
# Assuming sarah solves puzzles, we can say sarah hosts parties.
# Based on charlie solves puzzles, it is evident that alice hosts parties.
# Given that sarah solves puzzles, it follows that sarah hosts parties.
# Given that charlie solves puzzles, it follows that sarah solves puzzles.
# Based on charlie solves puzzles, it is evident that the festival hosts parties.
# If alice hosts parties, then the festival hosts parties.
# Given that sarah solves puzzles, it follows that the festival hosts parties.
# When the festival solves puzzles, we can conclude alice hosts parties.
# Based on sarah solves puzzles, it is evident that the festival solves puzzles.
# When sarah hosts parties, we can conclude sarah solves puzzles.
#
#
# The festival hosts parties.
#
#
# Given that when sarah solves puzzles, we can conclude sarah hosts parties, it is evident that sarah hosts parties.
# Applied Rule: since the fact that given that sarah hosts parties, it follows that sarah solves puzzles, we can see that sarah solves puzzles.
# Applied Rule: since the fact that based on sarah solves puzzles, it is evident that the festival solves puzzles, we can see that the festival solves puzzles.
# Applying the logic of if the festival solves puzzles, then alice hosts parties, we deduce that alice hosts parties.
# Given that when alice hosts parties, we can conclude the festival hosts parties, it is evident that the festival hosts parties.
#
#
# True
# --------------------
# Facts:
# The pig swims well.
# The pumpkin swims well.
# The mountain grows plants.
# Rules:
# Assuming the mountain grows plants, we can say the mountain swims well.
# When the pig swims well, we can conclude the mountain swims well.
# Based on the pumpkin swims well, it is evident that the mountain swims well.
# Assuming the mountain grows plants, we can say the mountain swims well.
# Assuming the pig swims well, we can say the mountain swims well.
# Given that the mountain swims well, it follows that chuan does yoga.
# When the pumpkin grows plants, we can conclude the pumpkin grows plants.
# When the pig is magical, we can conclude the pumpkin grows plants.
# Assuming chuan is magical, we can say the pig is magical.
# If the mountain grows plants, then chuan is magical.
#
#
# The pumpkin grows plants.
#
#
# Given that based on the mountain grows plants, it is evident that chuan is magical, it is evident that chuan is magical.
# Since we know that if chuan is magical, then the pig is magical, it follows that the pig is magical.
# Because based on the pig is magical, it is evident that the pumpkin grows plants, we can conclude that the pumpkin grows plants.
# Given that when the pumpkin grows plants, we can conclude the pumpkin grows plants, it is evident that the pumpkin grows plants.
#
#
# True
# --------------------
# Facts:
# Mike is blue.
# The shop plays games.
# The shop plays games.
# Rules:
# When the shop plays games, we can conclude the teacher is blue.
# If the shop plays games, then the teacher makes pizza.
# When the shop plays games, we can conclude mike is blue.
# Based on the shop plays games, it is evident that the teacher is blue.
# If the shop plays games, then mike is blue.
# Given that mike makes pizza, it follows that mike makes pizza.
# If the phone plays games, then mike makes pizza.
# Assuming the phone is blue, we can say the phone plays games.
# When the teacher is blue, we can conclude the phone is blue.
# When the phone is blue, we can conclude the teacher is blue.
#
#
# Mike makes pizza.
#
#
# Since we know that assuming the shop plays games, we can say the teacher is blue, it follows that the teacher is blue.
# Applying the logic of when the teacher is blue, we can conclude the phone is blue, we deduce that the phone is blue.
# Because if the phone is blue, then the phone plays games, we can conclude that the phone plays games.
# Applying the logic of if the phone plays games, then mike makes pizza, we deduce that mike makes pizza.
# Given that assuming mike makes pizza, we can say mike makes pizza, it is evident that mike makes pizza.
#
#
# True
# --------------------
# Facts:
# Mike carries bags.
# The computer makes pizza.
# Jack hikes mountains.
# Rules:
# If the computer makes pizza, then mike carries bags.
# Assuming jack hikes mountains, we can say the playground hikes mountains.
# Given that mike carries bags, it follows that mike makes pizza.
# Assuming mike carries bags, we can say the playground jumps high.
# Based on jack hikes mountains, it is evident that mike makes pizza.
# Assuming mike carries bags, we can say the playground makes pizza.
# Given that jack hikes mountains, it follows that mike carries bags.
# Given that the playground hikes mountains, it follows that mike carries bags.
# Based on jack jumps high, it is evident that the playground hikes mountains.
# If the playground hikes mountains, then jack jumps high.
#
#
# The playground makes pizza.
#
#
# Since we know that when jack hikes mountains, we can conclude the playground hikes mountains, it follows that the playground hikes mountains.
# Given that when the playground hikes mountains, we can conclude jack jumps high, it is evident that jack jumps high.
# Because based on jack jumps high, it is evident that the playground hikes mountains, we can conclude that the playground hikes mountains.
# Because based on the playground hikes mountains, it is evident that mike carries bags, we can conclude that mike carries bags.
# Applying the logic of when mike carries bags, we can conclude the playground makes pizza, we deduce that the playground makes pizza.
#
#
# True
# --------------------
